# %%
import matplotlib
import sys
import matplotlib.pyplot as plt

# %%
tempArr = []
fileName = "/home/pi/nohup.out"
fileObj = open(fileName)
for line in fileObj.readlines():
    arr = line.split(' ')
    if(len(arr) == 2):
        time = arr[0]
        temp = float(arr[1])/1000
        tempArr.append(temp)
fileObj.close()
plt.plot(tempArr)
plt.ylabel('CPU temperature')
plt.show()
